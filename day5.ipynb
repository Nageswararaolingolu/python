# %%
dct = {}
print("dct is represented :",dct,"type of dct :",type(dct))
# Out:
# dct is represented : {} type of dct : <class 'dict'>

# %%
dct = {
    "name" : "siddu",
    "age" : 21,
    "city" : "hyd"
}
print(dct)
# Out:
# {'name': 'siddu', 'age': 21, 'city': 'hyd'}

# %%
dct[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dct[0]
#
# KeyError: 0

# %%
dct["name"]
# Out:
# 'siddu'

# %%
dct["age"]
# Out:
# 21

# %%
dct["city"]
# Out:
# 'hyd'

# %%
dct["state"] = "tg"
print(dct)
# Out:
# {'name': 'siddu', 'age': 21, 'city': 'hyd', 'state': 'tg'}

# %%
dct["salary"]=30000
print(dct)
# Out:
# {'name': 'siddu', 'age': 21, 'city': 'hyd', 'state': 'tg', 'salary': 30000}

# %%
dct.update(
    {
        "role":"trainee",
        "salary":30000
    }
)
print(dct)
# Out:
# {'name': 'siddu', 'age': 21, 'city': 'hyd', 'state': 'tg', 'salary': 30000, 'role': 'trainee'}

# %%
print(dct.values())
# Out:
# dict_values(['siddu', 21, 'hyd', 'tg', 30000, 'trainee'])

# %%
print(dct.keys())
# Out:
# dict_keys(['name', 'age', 'city', 'state', 'salary', 'role'])

# %%
print(dct.items())
# Out:
# dict_items([('name', 'siddu'), ('age', 21), ('city', 'hyd'), ('state', 'tg'), ('salary', 30000), ('role', 'trainee')])

# %%
dct("location")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 dct("location")
#
# TypeError: 'dict' object is not callable

# %%
dct.get("location","not found")
# Out:
# 'not found'

# %%
dct.get("salary")
# Out:
# 30000

# %%
dct1={
    101:{"name:","siddu","role:","data analyst","age:",21},
    102:{"name:","akshay","role:","software","age:",22}
}
dct1
# Out:
# {101: {21, 'age:', 'data analyst', 'name:', 'role:', 'siddu'},
#  102: {22, 'age:', 'akshay', 'name:', 'role:', 'software'}}

# %%
dct1[101]["role"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 dct1[101]["role"]
#
# TypeError: 'set' object is not subscriptable

# %%
dct2 = {
    "name":"siddu",
    "name":"satish",
    "age":37
}
dct2
# Out:
# {'name': 'satish', 'age': 37}

# %%
dct2["name"]=["akshay"]
dct2
# Out:
# {'name': ['akshay'], 'age': 37}

# %%
marks={
    "maths":90,
    "science":90
}
marks
# Out:
# {'maths': 90, 'science': 90}

# %%
new_marks=marks.copy()
print(new_marks)
# Out:
# {'maths': 90, 'science': 90}

# %%
marks["english"]=66
new_marks
# Out:
# {'maths': 90, 'science': 90}

# %%
marks
# Out:
# {'maths': 90, 'science': 90, 'english': 66}

# %%
marks.pop("science")
marks
# Out:
# {'maths': 90, 'english': 66}

# %%
marks.popitem()
# Out:
# ('english', 66)

# %%
marks.clear()
marks
# Out:
# {}

# %%
###sets

# %%
set1={10,20,30,20,20}
print(set1)
print(type(set1))
# Out:
# {10, 20, 30}
# <class 'set'>

# %%
set2={70,80,80}
set1.update(set2)
print(set1)
# Out:
# {80, 20, 70, 10, 30}

# %%
set1.remove(30)
print(set1)
# Out:
# {80, 20, 70, 10}

# %%
set1.discard(100)

# %%
set1.pop()
set1
# Out:
# set()

# %%
set1.clear()
print(set1)
# Out:
# set()

# %%
a={1,2,3,4,5,6}
b={2,4,6,8}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
a={1,2,3,4,5,6}
b={2,4,6,8}
print(a.intersection(b))
# Out:
# {2, 4, 6}

# %%
a={1,2,3,4,5,6}
b={2,4,6,8}
print(a.symmetric_difference(b))
# Out:
# {1, 3, 5, 8}

# %%
python_students = {"ravi","priya"}
all_students = {"ravi","priya","anu","kiran"}
java_students = {"mahi","suresh"}

print(python_students.issubset(all_students))
# Out:
# True

# %%
print(all_students.issuperset(python_students))
# Out:
# True

# %%
print(all_students.isdisjoint(java_students))
# Out:
# True
