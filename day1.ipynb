# %% [markdown]
# print("Hello")

# %% [markdown]
# # i am siddu
# # lingolu siddu
# # data analyst
# # aspiring

# %%
NAME="SIDDU"
PRINT(NAME)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 NAME="SIDDU"
# ----> 2 PRINT(NAME)
#
# NameError: name 'PRINT' is not defined

# %%
name = "siddu"
print(name)
# Out:
# siddu

# %%
name = "siddu"
print(name)
# Out:
# siddu

# %%
print('siddu')
# Out:
# siddu

# %%
name = "siddu"
age = 21
salary = 28500.87
active = True

# %%
print("******Student Details******")
print(name)
print(type(name))
print(age)
print(type(age))
print(salary)
print(type(salary))
print(active)
print(type(active))
# Out:
# ******Student Details******
# siddu
# <class 'str'>
# 21
# <class 'int'>
# 28500.87
# <class 'float'>
# True
# <class 'bool'>

# %%
print("my name is",name)
# Out:
# my name is siddu

# %%
name = input(" enter a name ")
print("My name is",name)
# Out:
#  enter a name  siddu
# My name is siddu

# %%
value1=int(input("enter value"))
print(type(value1))
# Out:
# enter value 1
# <class 'int'>

# %%
a=10
b=20
print(a+b)
print(a-b)
# Out:
# 30
# -10

# %%
addition = a+b
subtraction = a-b

# %%
print("This is addition",addition)
print("This is subtraction",subtraction)
# Out:
# This is addition 30
# This is subtraction -10

# %%
addition1 = int(input("enter A value"))
addition2 = int(input("enter B value"))
print(addition1+addition2)
print(addition1-addition2)
# Out:
# enter A value 50
# enter B value 30
# 80
# 20

# %%
a = 10
b = 20
a>b
# Out:
# False

# %%
a=bool(input("A"))
b=bool(input("B"))
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# A 10
# B 20
# False
# False
# True
# True
