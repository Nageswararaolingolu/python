# %%
ls=[10,5,"siddu",True]
print(ls)
# Out:
# [10, 5, 'siddu', True]

# %%
print("before appens",ls)
ls.append(100)
print("after append",ls)
# Out:
# before appens [10, 5, 'siddu', True]
# after append [10, 5, 'siddu', True, 100]

# %%
print("before extendd:",ls)
ls.extend([100,"siddu",False])
print("after extendd:",ls)
# Out:
# before extendd: [10, 5, 'siddu', True, 100]
# after extendd: [10, 5, 'siddu', True, 100, 100, 'siddu', False]

# %%
print("before extend:",ls)
ls1=[20,30,"surya"]
print("ls1:",ls1)
ls.extend(ls1)
print("after extend1:",ls)
# Out:
# before extend: [10, 5, 'siddu', True, 100, 100, 'siddu', False]
# ls1: [20, 30, 'surya']
# after extend1: [10, 5, 'siddu', True, 100, 100, 'siddu', False, 20, 30, 'surya']

# %%
ls2=[1,2,3,4]
print(ls2)
# Out:
# [1, 2, 3, 4]

# %%
ls2.insert(2,44)
print(ls2)
# Out:
# [1, 2, 44, 3, 4]

# %%
ls3=ls2.copy()
print(ls3)
# Out:
# [1, 2, 44, 3, 4]

# %%
ls2.append(45)
print(ls2)
print(ls3)
# Out:
# [1, 2, 44, 3, 4, 45, 45]
# [1, 2, 44, 3, 4]

# %%
print(ls)
print(ls.count(1))
# Out:
# [10, 5, 'siddu', True, 100, 100, 'siddu', False, 20, 30, 'surya']
# 1

# %%
print(ls2)
# Out:
# [1, 2, 44, 3, 4, 45, 45]

# %%
ls2.sort()
print(ls2)
# Out:
# [1, 2, 3, 4, 44, 45, 45]

# %%
print(ls)
ls.sort()
# Out:
# [10, 5, 'siddu', True, 100, 100, 'siddu', False, 20, 30, 'surya']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 print(ls)
# ----> 2 ls.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
print(ls2)
ls2.sort(reverse = True)
print(ls2)
# Out:
# [45, 45, 44, 4, 3, 2, 1]
# [45, 45, 44, 4, 3, 2, 1]

# %%
ls2.reverse()
print(ls2)
# Out:
# [1, 2, 3, 4, 44, 45, 45]

# %%
ls2.remove(4)
print(ls2)
# Out:
# [1, 2, 3, 44, 45, 45]

# %%
ls2.pop()
print(ls2)
# Out:
# [1, 2, 3, 44, 45]

# %%
ls2.pop(1)
print(ls2)
# Out:
# [1, 3, 44, 45]

# %%
ls2.clear()
print(ls2)
# Out:
# []
