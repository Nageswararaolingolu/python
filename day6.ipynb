# %%
str1 = "welcoME To PythOn Class"
print("lower:",str1.lower())
print("upper:",str1.upper())
print("title::",str1.title())
print("capitalize::",str1.capitalize())
print("swapcase:",str1.swapcase())
# Out:
# lower: welcome to python class
# upper: WELCOME TO PYTHON CLASS
# title:: Welcome To Python Class
# capitalize:: Welcome to python class
# swapcase: WELCOme tO pYTHoN cLASS

# %%
str1 = "    siddu   "
print(str1)
print("strip:",str1.strip())
print("lstrip:",str1.lstrip())
print("rstrip:",str1.rstrip())
# Out:
#     siddu
# strip: siddu
# lstrip: siddu
# rstrip:     siddu

# %%
str1 = "Today is python class"
print("replace:",str1.replace("python","excel"))
# Out:
# replace: Today is excel class

# %%
str1 = "pythonn"
print("count:",str1.count("n"))
print("find:",str1.find("n"))
print("index:",str1.index("n"))
print("find:",str1.find("z"))
# Out:
# count: 2
# find: 5
# index: 5
# find: -1

# %%
#split and join
#join works only on splitted data
str1 = "welcome to python"
remove = str1.split(" ")
print(remove)
# Out:
# ['welcome', 'to', 'python']

# %%
str1 = " ".join(remove)
print(str1)
# Out:
# welcome to python

# %%
str1 = "python"
print("startwith:",str1.startswith("p"))
print("endswith:",str1.endswith("n"))
# Out:
# startwith: True
# endswith: True

# %%
str2 = "323456"
print("is numeric:",str2.isalpha())
print("is numeric:",str2.isnumeric())
print("is numeric:",str2.isdigit())
print("is numeric:",str2.isdecimal())
# Out:
# is numeric: False
# is numeric: True
# is numeric: True
# is numeric: True
