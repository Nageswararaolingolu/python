# %% [markdown]
# Assignment operator

# %%
a=5
print(a)
# Out:
# 5

# %%
a=(a+5)
print(a)
# Out:
# 10

# %%
a+=5
print(a)
# Out:
# 15

# %%
a-=5
print(a)
# Out:
# 10

# %%
wallet = 5000
wallet += 1500
wallet -= 400
wallet *= 3

# %%
print(wallet)
# Out:
# 18300

# %% [markdown]
# ##Logical operators AND OR NOT

# %%
age = int(input(a))
salary = 25000
if age >= 18 and salary >= 25000:
    print("Eligible for loan")
else:print("Not Eligible")
# Out:
# 10 20
# Eligible for loan

# %%
marks = int(input(a))
if marks >= 90:
    print("A")
elif marks >= 75:
    print("B")
elif marks >= 35:
    print("C")
else : print("F")
# Out:
# 10 30
# F

# %% [markdown]
# ##Nested if

# %%
age = int(input(age))
salary = int(input(salary))
if age >= 18:
    if salary >= 20000:
        print("Eligible for loan")
    else:
        print("not eligible because salary not match")
else:
    print(" age criteria Underage")
# Out:
# 17 17
# 10000 210000
#  age criteria Underage

# %%
account_balance = 20000
withdraw_amount = int(input("amount"))
if withdraw_amount <= 20000:
    pin = int(input("enter pin"))
    if pin == 1234:
       print("withdraw is successfull")
       print("correct pin")
    else:print("incorrect pin")
else:
       print("insufficient balance")
# Out:
# amount 1000
# enter pin 1234
# withdraw is successfull
# correct pin

# %%
amount = 3000
order_amount = int(input("enter amount"))
membership = input("enter membership")
if order_amount >= 3000 and membership == "yes":
          print("20% discount")
elif order_amount >= 3000 and membership == "no":
    print("10% discount")
elif order_amount >= 1500 and membership == "any":
    print("any free desert")
else:
    print("no offer")
# Out:
# enter amount 3000
# enter membership yes
# 20% discount
